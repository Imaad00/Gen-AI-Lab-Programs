# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\shrey\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: torchvision in c:\users\shrey\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: torchaudio in c:\users\shrey\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: filelock in c:\users\shrey\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\shrey\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\shrey\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\shrey\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\shrey\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\shrey\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\shrey\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: numpy in c:\users\shrey\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\shrey\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrey\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.7.0+cpu
# False

# %%
# Install gensim for downloading pre-trained models
# !pip install gensim

# Install Hugging Face Transformers for NLP pipelines
# !pip install transformers
# !pip install tensorflow

# Install NLTK for text preprocessing and tokenization
# !pip install nltk

# [2] - Import libraries
import torch
import gensim.downloader as api
from transformers import pipeline
import nltk
import string
from nltk.tokenize import word_tokenize

# Download the 'punkt' resource from NLTK
nltk.download('punkt')

print("Loading pre-trained word vectors...")
word_vectors = api.load("glove-wiki-gigaword-100")  # Load Word2Vec model

# [6] - Function to replace words in the prompt with their most similar words
def replace_keyword_in_prompt(prompt, keyword, word_vectors, topn=1):
    """
    Replace only the specified keyword in the prompt with its most similar word.

    Args:
        prompt (str): The original input prompt.
        keyword (str): The word to be replaced with a similar word.
        word_vectors (gensim.models.KeyedVectors): Pre-trained word embeddings.
        topn (int): Number of top similar words to consider (default: 1).

    Returns:
        str: The enriched prompt with the keyword replaced.
    """
    words = word_tokenize(prompt)  # Tokenize the prompt into words
    enriched_words = []

    for word in words:
        cleaned_word = word.lower().strip(string.punctuation)  # Normalize word
        if cleaned_word == keyword.lower():  # Replace only if it matches the keyword
            try:
                # Retrieve similar word
                similar_words = word_vectors.most_similar(cleaned_word, topn=topn)
                if similar_words:
                    replacement_word = similar_words[0][0]  # Choose the most similar word
                    print(f"Replacing '{word}' → '{replacement_word}'")
                    enriched_words.append(replacement_word)
                else:
                    enriched_words.append(word)
            except KeyError:
                print(f"'{keyword}' not found in the vocabulary. Using original word.")
                enriched_words.append(word)
        else:
            enriched_words.append(word)  # Keep original if no replacement was made

    enriched_prompt = ' '.join(enriched_words)
    print(f"\nEnriched Prompt: {enriched_prompt}")
    return enriched_prompt

# [7] - Install torch and related libraries
# !pip install torch torchvision torchaudio

# [8] - Load an open-source Generative AI model (GPT-2)
print("\nLoading GPT-2 model...")
generator = pipeline("text-generation", model="gpt2", framework="pt")

# [9] - Function to generate responses using the Generative AI model
def generate_response(prompt, max_length=100):
    try:
        response = generator(prompt, max_length=max_length, num_return_sequences=1)
        return response[0]['generated_text']
    except Exception as e:
        print(f"Error generating response: {e}")
        return None

# [10] - Example original prompt
original_prompt = "Who is king."
print("\n Original Prompt: {original_prompt}")

# [11] - Retrieve similar words for key terms in the prompt
key_term = "king"

enriched_prompt = replace_keyword_in_prompt(original_prompt, key_term, word_vectors)

# [13] - Generate responses for the original and enriched prompts
print("\nGenerating response for the original prompt...")
original_response = generate_response(original_prompt)
print("Original Prompt Response:")
print(original_response)

print("\nGenerating response for the enriched prompt...")
enriched_response = generate_response(enriched_prompt)
print("Enriched Prompt Response:")
print(enriched_response)

# [14] - Compare the outputs of responses
print("\nComparison of Responses:")
print("Original Prompt Response Length:", len(original_response))
print("Enriched Prompt Response Length:", len(enriched_response))
print("Original Prompt Response Details:", original_response.count('.'))
print("Enriched Prompt Response Details:", enriched_response.count('.'))
# Out:
# Requirement already satisfied: gensim in c:\users\shrey\anaconda3\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\shrey\anaconda3\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\shrey\anaconda3\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\shrey\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: transformers in c:\users\shrey\anaconda3\lib\site-packages (4.51.3)
# Requirement already satisfied: filelock in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\shrey\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shrey\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\shrey\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrey\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrey\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrey\anaconda3\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: tensorflow in c:\users\shrey\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\shrey\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shrey\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\shrey\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\shrey\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\shrey\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shrey\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrey\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrey\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrey\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shrey\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shrey\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shrey\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shrey\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shrey\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shrey\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: nltk in c:\users\shrey\anaconda3\lib\site-packages (3.9.1)Loading pre-trained word vectors...
#
# Requirement already satisfied: click in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\shrey\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\shrey\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: torch in c:\users\shrey\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: torchvision in c:\users\shrey\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: torchaudio in c:\users\shrey\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: filelock in c:\users\shrey\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\shrey\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\shrey\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\shrey\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\shrey\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\shrey\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\shrey\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: numpy in c:\users\shrey\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\shrey\anaconda3\lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shrey\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrey\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
#
# Loading GPT-2 model...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 69
#      67 # [8] - Load an open-source Generative AI model (GPT-2)
#      68 print("\nLoading GPT-2 model...")
# ---> 69 generator = pipeline("text-generation", model="gpt2", framework="pt")
#      71 # [9] - Function to generate responses using the Generative AI model
#      72 def generate_response(prompt, max_length=100):
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:942, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     940 if isinstance(model, str) or framework is None:
#     941     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 942     framework, model = infer_framework_load_model(
#     943         adapter_path if adapter_path is not None else model,
#     944         model_classes=model_classes,
#     945         config=config,
#     946         framework=framework,
#     947         task=task,
#     948         **hub_kwargs,
#     949         **model_kwargs,
#     950     )
#     952 model_config = model.config
#     953 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\base.py:242, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     216 """
#     217 Select framework (TensorFlow or PyTorch) to use from the `model` passed. Returns a tuple (framework, model).
#     218
#    (...)
#     239     `Tuple`: A tuple framework, model.
#     240 """
#     241 if not is_tf_available() and not is_torch_available():
# --> 242     raise RuntimeError(
#     243         "At least one of TensorFlow 2.0 or PyTorch should be installed. "
#     244         "To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ "
#     245         "To install PyTorch, read the instructions at https://pytorch.org/."
#     246     )
#     247 if isinstance(model, str):
#     248     model_kwargs["_from_pipeline"] = task
#
# RuntimeError: At least one of TensorFlow 2.0 or PyTorch should be installed. To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ To install PyTorch, read the instructions at https://pytorch.org/.
